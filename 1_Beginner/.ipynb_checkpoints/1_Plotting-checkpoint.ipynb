# %%
'''
Visualization - Beginner level
'''

# %%
# ======================= Import Data  =======================
# Use the pandas library to read data into a table (dataframe)
import pandas as pd
import matplotlib.pyplot as plt

fname =  "../dataset/daily_house_elec.csv"
dataframe = pd.read_csv(fname, index_col=0, parse_dates=True) # Insert your own filename

dataframe.tail()
# Out:
#             power_consumption
# date
# 2010-12-07            285.912
# 2010-12-08            169.098
# 2010-12-09            201.358
# 2010-12-10            170.268
# 2010-12-11            151.144

# %%
# Select one column (index is kept)
cons = dataframe['power_consumption']

# %%
# ======================= Visualization =======================
# Line Plot
# Inside the 'series' object, there is a function called "plot" which graphs the data:
cons.plot(figsize=(16,6))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3e9d1fa28652> in <module>
#       3 # Inside the 'series' object, there is a function called "plot" which graphs the data:
#       4 cons.plot(figsize=(16,6))
# ----> 5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# <Customize the plot>
# We import a module, with the nickname "plt":
import matplotlib.pyplot as plt
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/home/jf/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
cons.plot(figsize=(16,6))

# Inside this module, the function "title" 
# allows you to set the "title" (attribute) of the "plot" (object)
print("Type:", type(plt.title))  
print("Parameters of the function:", plt.title) 
plt.title('Electricity Consumption')
print("Value of the 'plot' attribute:", plt.title)

# Same for all other functions:
plt.xlabel('Date & Time')
plt.ylabel('Electricity Consumption (Wh)')
# Out:
# Type: <class 'function'>
# Parameters of the function: <function title at 0x7f01fadbb9e0>
# Value of the 'plot' attribute: <function title at 0x7f01fadbb9e0>
# Text(0, 0.5, 'Electricity Consumption (Wh)')
